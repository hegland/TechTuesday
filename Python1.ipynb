# %% [markdown]
# ## Tech Tuesday VSCode with Jupyter and Python to start

# %%
# print Hello World
print("Hello World")
# Out:
# Hello World

# %%
# install the numpy package
# !pip install numpy
# install the matplotlib package
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Downloading numpy-1.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 9.5 MB/s eta 0:00:000m eta 0:00:010:00:01
# Installing collected packages: numpy
# Successfully installed numpy-1.26.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 10.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/hegland/.local/lib/python3.10/site-packages (from matplotlib) (23.1)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.42.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 10.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.7/301.7 KB 8.0 MB/s eta 0:00:000:00:01
# Requirement already satisfied: numpy<2,>=1.21 in /home/hegland/.local/lib/python3.10/site-packages (from matplotlib) (1.26.0)
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 10.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/hegland/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/hegland/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.11.0 fonttools-4.42.1 kiwisolver-1.4.5 matplotlib-3.8.0 pillow-10.0.1

# %%
# plot f(x) = sin(x) for x in [0, 2pi]
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
plt.plot(x, y)

# add axis labels and title
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('Plot of sin(x)')


# add grid lines
plt.grid(True)

# save the figure as a pdf
plt.savefig('sinx.pdf')


plt.show()

# %% [markdown]
# ## Numerical linear algebra
#
# ### a random matrix

# %%
m = 3   # number of rows
n = 4   # number of columns

# generate a random m x n matrix M
M = np.random.rand(m, n)
# print M with label and newline
print('M =  \n', M, '\n')

# print the singular values of M with label and newline at the end
print('singular values of M = ', np.linalg.svd(M)[1], '\n')
# Out:
# M =
#  [[0.88404105 0.11504204 0.70230065 0.91263517]
#  [0.78298761 0.35465856 0.20753887 0.33042905]
#  [0.67558522 0.45274921 0.83363756 0.68741422]]
#
# singular values of M =  [2.13268898 0.43072008 0.32711696]

# %% [markdown]
# ### a compound matrix

# %%
# generate a set Sm containing the numbers 1, 2, ..., m
Sm = set(range(0, m))
# generate a set Tn containing the numbers 1, 2, ..., n
Tn = set(range(0, n))

k = 2

# generate all subsets S of Sm of size k
from itertools import combinations
Sc = list(combinations(Sm, k))
print(Sc)

# generate all subsets T of Tn of size k
Tc = list(combinations(Tn, k))
print(Tc)

# generate a matrix C of all determinants of the k x k submatrices of M
C = np.zeros((len(Sc), len(Tc)))
# loop over all elements of Sc
for i in range(len(Sc)):
    S = Sc[i]
    # loop over all elements of Tc
    for j in range(len(Tc)):
        T = Tc[j]
        C[i,j] = np.linalg.det(M[np.ix_(S, T)])

print(C.shape)
print(C)
# Out:
# [(0, 1), (0, 2), (1, 2)]
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]
# (3, 6)
# [[ 0.19487673 -0.2032248  -0.13410019 -0.49814991 -0.46273018  0.13976142]
#  [ 0.02194903 -0.11958625 -0.03412969 -0.09892491 -0.06054227  0.17603272]
#  [-0.1448401   0.0847773   0.0866299   0.20924599  0.31224154 -0.0576086 ]]
